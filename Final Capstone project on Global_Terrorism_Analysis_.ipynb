# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavmande131198/Global_Terrorism_Analysis/blob/main/Final%20Capstone%20project%20on%20Global_Terrorism_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Project Name - Global Terrorism Analysis**
#
# ####**Project Type** - EDA
# ####**Contribution** - Individual

# %% [markdown]
# ###**Project Summary**

# %% [markdown]
# In this EDA project, we were provided with the Global Terrorism Database (GTD) which is a database including information on terrorist events around the world from 1970 through 2017. Unlike many other event databases, the GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 181,000 cases.
#
# In this project we are doing the exploratory data analysis on the global terrorisam database to find out various insights of terrorism activity and their effect over region,country and city.
# Also we did some visualizations for easy understandings of the analysis.
#
# After analyzing the cleaned data, we divided the project into various types of analysis. The first is the analysis based on Trend of Terrorrism Per Year the second is the analysis based on Most affected areas of Terrorism. Third analysis based on Terrorist Organization and the last analysis is based on country.
#
# In the EDA we have conclude that after 2011 there is a large growth recorded in terrorist activity and 2014 appears to be a witness of huge terrorist attack.

# %% [markdown]
# ##**GitHub link -**

# %% [markdown]
# https://github.com/vaibhavmande131198/Global_Terrorism_Analysis.git

# %% [markdown]
# ##**Problem Statement**

# %% [markdown]
# ***The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.***
#
# ***Explore and analyze the data to discover key findings pertaining to terrorist activities***

# %% [markdown]
# ###**Objective -**

# %% [markdown]
# 1.Studies in Conflict and Terrorism aims to cast new light on the origins and implications of conflict in the 21st Century and to illuminate new approaches and solutions to countering the growth and escalation of contemporary sub-state violence.
#
# 2.The main objective of the project is to find out the effect of terrorism in the world and spread awareness to reduce the violence

# %% [markdown]
# ##**Let's Begin !**

# %% [markdown]
# ###Importing The Libraries

# %%
# importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ###Loading the Dataset

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Location of the datafile
file_path=('/content/drive/MyDrive/Colab Notebooks/Almabetter data science/Python for data science/python:- capeston project/Global Terrorism Data.csv')

# %%
# read the dataset
df=pd.read_csv(file_path,encoding="ISO-8859-1")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.head(2)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
#
# [2 rows x 135 columns]

# %%
df.tail(2)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  scite3  \
# 181689                                                NaN     NaN
# 181690  "Security tightened in Cotabato City," Manila ...     NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ####**Checking Duplicate Events**

# %%
# check the duplicate event from eventid
df['eventid'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###**What did you know about your dataset?**

# %% [markdown]
# In the Global Terrorism Database there are 181691 rows which describe the number of attacks happen between year 1970 to 2017. And there are 135 columns which includes various information about the terrorism.
#
# There is not a single duplicate event in the dataset.
#
# Also there are some null valus in the various column. so we have to replace it with zero for further calculations.

# %% [markdown]
# ##**Data Wrangling**

# %% [markdown]
# ###Cleaning and Managing the data

# %% [markdown]
# As we dont want to make changes in our original dataframe. We made one copy of the dataset and made the changes that we needed in the copy of the dataset

# %%
new_df=df.copy()

# %%
new_df.shape
# Out:
# (181691, 135)

# %%
new_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
new_df.columns[0:20]
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity',
#        'location', 'summary', 'crit1'],
#       dtype='object')

# %%
new_df.columns[20:40]
# Out:
# Index(['crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt',
#        'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1'],
#       dtype='object')

# %%
new_df.columns[40:60]
# Out:
# Index(['natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2',
#        'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
#        'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt',
#        'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname'],
#       dtype='object')

# %%
new_df.columns[60:80]
# Out:
# Index(['gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1',
#        'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap',
#        'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt'],
#       dtype='object')

# %%
new_df.columns[80:100]
# Out:
# Index(['compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus'],
#       dtype='object')

# %%
new_df.columns[100:120]
# Out:
# Index(['nkillter', 'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'nhostkid',
#        'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry', 'ransom',
#        'ransomamt', 'ransomamtus', 'ransompaid'],
#       dtype='object')

# %%
new_df.columns[120:136]
# Out:
# Index(['ransompaidus', 'ransomnote', 'hostkidoutcome', 'hostkidoutcome_txt',
#        'nreleased', 'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource',
#        'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object')

# %% [markdown]
# from the above column list theare are many columns which are not needed for the analysis. so we are keeping those columns which are useful to us

# %% [markdown]
# Rename those columns which are needed

# %%
# Rename the columns for easy understanding
new_df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','city':'City','provstate':'State',
                          'region_txt':'Region','attacktype1_txt':'Attack_Type','targtype1_txt':'Main_Target','nkill':'Killed',
                          'nwound':'Wounded','gname':'Gang_Name',
                          'weaptype1_txt':'Weapon_type','latitude':'Latitude',
                          'longitude':'Longitude','targsubtype1_txt':'Sub_Target',
                          'natlty1_txt':'Nationality','motive':'Motive','summary':'Summary'},inplace=True)

# %% [markdown]
# Keep those columns which are important for analysis

# %%
# columns_to_keep=['Year','Month','Day','City','Region','Latitude','Country','State','Longitude','Attack_Type','Killed','Gang_Name','Wounded','Main_Target','Sub_Target','Weapon_type','Motive','Nationality']

# %%
new_df=new_df[['Year','Month','Day','Latitude','Longitude','Region','Country','State','City','Attack_Type','Killed','Gang_Name','Wounded','Main_Target','Sub_Target','Weapon_type','Motive','Nationality']]

# %% [markdown]
# ###**Understanding the variable**

# %%
new_df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Latitude', 'Longitude', 'Region', 'Country',
#        'State', 'City', 'Attack_Type', 'Killed', 'Gang_Name', 'Wounded',
#        'Main_Target', 'Sub_Target', 'Weapon_type', 'Motive', 'Nationality'],
#       dtype='object')

# %%
new_df.shape
# Out:
# (181691, 18)

# %%
new_df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
new_df.head(2)
# Out:
#    Year  Month  Day   Latitude  Longitude                       Region  \
# 0  1970      7    2  18.456792 -69.951164  Central America & Caribbean
# 1  1970      0    0  19.371887 -99.086624                North America
#
#               Country    State           City                  Attack_Type  \
# 0  Dominican Republic      NaN  Santo Domingo                Assassination
# 1              Mexico  Federal    Mexico city  Hostage Taking (Kidnapping)
#
#    Killed                           Gang_Name  Wounded  \
# 0     1.0                              MANO-D      0.0
# 1     0.0  23rd of September Communist League      0.0
#
#                    Main_Target  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
#
#                                           Sub_Target Weapon_type Motive  \
# 0                                     Named Civilian     Unknown    NaN
# 1  Diplomatic Personnel (outside of embassy, cons...     Unknown    NaN
#
#           Nationality
# ...

# %%
new_df.tail(2)
# Out:
#         Year  Month  Day   Latitude   Longitude          Region      Country  \
# 181689  2017     12   31  24.798346   93.940430      South Asia        India
# 181690  2017     12   31   7.209594  124.241966  Southeast Asia  Philippines
#
#               State           City        Attack_Type  Killed Gang_Name  \
# 181689      Manipur         Imphal  Bombing/Explosion     0.0   Unknown
# 181690  Maguindanao  Cotabato City  Bombing/Explosion     0.0   Unknown
#
#         Wounded           Main_Target                           Sub_Target  \
# 181689      0.0  Government (General)  Government Building/Facility/Office
# 181690      0.0               Unknown                                  NaN
#
#        Weapon_type Motive  Nationality
# 181689  Explosives    NaN        India
# 181690  Explosives    NaN  Philippines

# %% [markdown]
# ###**Variable Description**

# %% [markdown]
# Year :- Year of Terrorist Attack
#
# Month :- Months of Terrorist Attack
#
# Day :- On which Day Terrorist Attack is happend
#
# Latitude :- Y Co-ordinates of Terrorist Attack point
#
# Longitude :- X Co-ordinate of Terrorist Attack point
#
# Region :- Regions in which Terrorist Attack happens
#
# Country :- Countries in which Terrorist Attack happens
#
# State :- States in which Terrorist Attack happens
#
# City :- Cities in which Terrorist Attack happens
#
# Attack_Type :- Type of Terrorist Attack
#
# Killed :- Number of people killed in the Terrorist Attack
#
# Gang_Name :- Name of Terrorist Organization
#
# Wounded :- Number of people Injured in the Terrorist Attack
#
# Main_Target :- Main taget of the Terrorist Attack
#
# Sub_Target :- Sub target of Terrorist Attack
#
# Weopan_type :- Weopan used in the Terrorist Attack
#
# Motive :- Motive of Terrorist Attack
#
# Nationality :- Nationality of Terrorist Organization
#
# Casualties :- It is the Sum of Number of people killed and Number  of people Injured in the Terrorist Attack

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Latitude     177135 non-null  float64
#  4   Longitude    177134 non-null  float64
#  5   Region       181691 non-null  object
#  6   Country      181691 non-null  object
#  7   State        181270 non-null  object
#  8   City         181257 non-null  object
#  9   Attack_Type  181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Gang_Name    181691 non-null  object
#  12  Wounded      165380 non-null  float64
#  13  Main_Target  181691 non-null  object
#  14  Sub_Target   171318 non-null  object
#  15  Weapon_type  181691 non-null  object
#  16  Motive       50561 non-null   object
#  17  Nationality  180132 non-null  object
# ...

# %%
#checking the total number of null values of the columns
new_df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Latitude         4556
# Longitude        4557
# Region              0
# Country             0
# State             421
# City              434
# Attack_Type         0
# Killed          10313
# Gang_Name           0
# Wounded         16311
# Main_Target         0
# Sub_Target      10373
# Weapon_type         0
# Motive         131130
# Nationality      1559
# dtype: int64

# %% [markdown]
# From the above data, We can see that there are many columns which has null values

# %% [markdown]
# There is no need to remove null values of all the columns. instead we are replacing the null values of killed and wounded column with zero

# %%
# fetch the null value of killed column
new_df[new_df['Killed'].isnull()].head(2)
# Out:
#    Year  Month  Day   Latitude   Longitude          Region Country    State  \
# 3  1970      1    0  37.997490   23.762728  Western Europe  Greece   Attica
# 4  1970      1    0  33.580412  130.396361       East Asia   Japan  Fukouka
#
#       City                     Attack_Type  Killed Gang_Name  Wounded  \
# 3   Athens               Bombing/Explosion     NaN   Unknown      NaN
# 4  Fukouka  Facility/Infrastructure Attack     NaN   Unknown      NaN
#
#                Main_Target         Sub_Target Weapon_type Motive  \
# 3  Government (Diplomatic)  Embassy/Consulate  Explosives    NaN
# 4  Government (Diplomatic)  Embassy/Consulate  Incendiary    NaN
#
#      Nationality
# 3  United States
# 4  United States

# %%
# fetch the null value of Wounded column
new_df[new_df['Wounded'].isnull()].head(2)
# Out:
#    Year  Month  Day   Latitude   Longitude          Region Country    State  \
# 3  1970      1    0  37.997490   23.762728  Western Europe  Greece   Attica
# 4  1970      1    0  33.580412  130.396361       East Asia   Japan  Fukouka
#
#       City                     Attack_Type  Killed Gang_Name  Wounded  \
# 3   Athens               Bombing/Explosion     NaN   Unknown      NaN
# 4  Fukouka  Facility/Infrastructure Attack     NaN   Unknown      NaN
#
#                Main_Target         Sub_Target Weapon_type Motive  \
# 3  Government (Diplomatic)  Embassy/Consulate  Explosives    NaN
# 4  Government (Diplomatic)  Embassy/Consulate  Incendiary    NaN
#
#      Nationality
# 3  United States
# 4  United States

# %%
# replace all the null value of killed column with 0
new_df.loc[new_df['Killed'].isna(),'Killed']= 0

# %%
# replace all the null value of Wounded column with 0
new_df.loc[new_df['Wounded'].isna(),'Wounded']= 0

# %%
# checking the replaced value
new_df.loc[3:4,'Killed':'Wounded']
# Out:
#    Killed Gang_Name  Wounded
# 3     0.0   Unknown      0.0
# 4     0.0   Unknown      0.0

# %% [markdown]
# Successfully replace the null value of killed and wounded column with zero

# %%
# now lets create one column named Casualties by using killed and wounded column

# %%
new_df['Casualties']=new_df['Killed']+new_df['Wounded']

# %%
new_df.shape
# Out:
# (181691, 19)

# %%
new_df.head(2)
# Out:
#    Year  Month  Day   Latitude  Longitude                       Region  \
# 0  1970      7    2  18.456792 -69.951164  Central America & Caribbean
# 1  1970      0    0  19.371887 -99.086624                North America
#
#               Country    State           City                  Attack_Type  \
# 0  Dominican Republic      NaN  Santo Domingo                Assassination
# 1              Mexico  Federal    Mexico city  Hostage Taking (Kidnapping)
#
#    Killed                           Gang_Name  Wounded  \
# 0     1.0                              MANO-D      0.0
# 1     0.0  23rd of September Communist League      0.0
#
#                    Main_Target  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
#
#                                           Sub_Target Weapon_type Motive  \
# 0                                     Named Civilian     Unknown    NaN
# 1  Diplomatic Personnel (outside of embassy, cons...     Unknown    NaN
#
# ...

# %%
new_df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded     Casualties
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ##Analysis and visualization of data

# %% [markdown]
# ###Number of Terrorist Attacks per year/ Yearly growth of terrorist attacks.

# %%
# number of attacks per year.
Attacks_per_year=new_df['Year'].value_counts()
Attacks_per_year
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: Year, dtype: int64

# %%
plt.figure(figsize = (25,8))
sns.lineplot(Attacks_per_year.index, Attacks_per_year.values)
plt.title('Number of Terrorist Attacks per year',fontsize=20)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Number of attacks',fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# We find out the number of attacks per year using value_counts() method.from this analysis it is clearly seen that there are increase in the number of attacks year by year. So to plot the trend of yearly growth in the terrorim attacks we use line plot

# %% [markdown]
# Observation :-
#
#  1.From the above graph we can say that After 2004 there is a large growth recorded in terrorist attack.
#
#  2.Maximum Number of the attacks were recorded in year 2014
#
#  3.Minimum number of attacks were recorded in the year 1971

# %% [markdown]
# ###Number of people killed per year due to Terrorist Attack

# %%
# number of people killed per year in the terrorist activity
Killed_per_year=new_df.groupby('Year')['Killed'].sum().sort_values(ascending=False)
Killed_per_year
# Out:
# Year
# 2014    44490.0
# 2015    38853.0
# 2016    34871.0
# 2017    26445.0
# 2013    22273.0
# 2012    15497.0
# 2007    12824.0
# 1997    10924.0
# 1984    10450.0
# 1992     9742.0
# 1983     9444.0
# 2006     9380.0
# 2009     9273.0
# 2008     9157.0
# 1991     8429.0
# 2011     8246.0
# 1989     8152.0
# 2010     7827.0
# 2001     7729.0
# 1994     7690.0
# 1988     7208.0
# 1990     7148.0
# 1985     7094.0
# 1996     6966.0
# 1987     6482.0
# 2005     6331.0
# 1995     6103.0
# 2004     5743.0
# 1982     5136.0
# 1986     4976.0
# 1981     4851.0
# 2002     4805.0
# 1998     4688.0
# 2000     4403.0
# 1980     4400.0
# 1999     3393.0
# 2003     3317.0
# 1979     2100.0
# 1978     1459.0
# 1976      674.0
# 1975      617.0
# 1972      566.0
# 1974      539.0
# 1977      456.0
# 1973      370.0
# 1970      174.0
# 1971      173.0
# Name: Killed, dtype: float64

# %%
plt.figure(figsize = (25,8))
sns.barplot(Killed_per_year.index, Killed_per_year.values,palette='viridis')
plt.title('Number of peope killed per year',fontsize=20)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Number of people killed',fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# We want exact number of people killed per year in the Terrorist activity so we plot bar chart for easy understanding

# %% [markdown]
# Observation:-
#
# 1.Due to increase in terrorism activity after 2004 ,number of people killed per year is also increases.
#
# 2.Most Number of People killed in year 2014.
#
# 3.Minimum Number of People killed in year 1971.

# %% [markdown]
# ###Analysis based on Most affected area of Terrorism
#
#
# ---

# %% [markdown]
# ####1.Top 10 Most affected Region

# %%
# Distribution of attacks all over the world
title='distribution of terrorist attack'
plt.figure(figsize=(20,8))
sns.scatterplot(new_df.Longitude,new_df.Latitude,hue=new_df.Region).set_title(title)
plt.xlim(-200, 200)
plt.ioff()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# We want to get the exact co-ordinates of the terrorist attacks and want to find out most affected region of the Terrorism, So we plot scatter plot.

# %% [markdown]
# Observation:-
#
# 1.From the scatter plot we can say that Middle East and North America is the most affected region of Terrorist Attack.
#
# 2.Australasia & Oceania is the most safest region because there is less number of Terrorism compare to other region.

# %%
#Most affected region of terrorism.
Most_affected_region=new_df['Region'].value_counts().head(10)
Most_affected_region
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: Region, dtype: int64

# %%
plt.figure(figsize = (15,5))
sns.barplot(Most_affected_region.index, Most_affected_region.values)
plt.title('Top 10 most attacked Region',fontsize=15)
plt.xlabel('Region Names',fontsize=15)
plt.ylabel('No. of attacks',fontsize=15)
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# 1.From the scatter plot we get distribution of Terrorist attacks in all regions,But we can't figure out exact number of attacks in particular region.
#
# 2.So to get clear idea of number of attacks per region we are using bar graph by doing exploratory data analysis on regions

# %% [markdown]
# Observation:-
#
# 1.Graph shows Top 10 Most affected region of terrorism.
#
# 2.We can say that Terrorist Groups are most active in the region of Middle East & North Africa and South Asia.
#
# 3.Most number of attacks happen in this regions only.

# %% [markdown]
# ####2.Top 10 Most affected Country

# %%
# Most affected Country of terrorism
Most_affected_country=new_df['Country'].value_counts().head(10)
Most_affected_country
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
plt.figure(figsize = (15,5))
sns.barplot(Most_affected_country.index, Most_affected_country.values, 
            palette='mako')
plt.title('Top 10 most attacked country',fontsize=15)
plt.xlabel('Country Names',fontsize=15)
plt.ylabel('No. of attacks',fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# To get exact count of number of attack in the Most affected country we use Bar plot.

# %% [markdown]
# Observation:-
#
# 1.Iraq is the most affected country of terrorism which records highest number of terrorism activity in any country.
#
# 2.India ranked number 4 in terms of most affected country of the terrorist activity

# %% [markdown]
# ####3.Top 10 Most affected City

# %%
# Most affected city of terrorism
Most_affected_City=new_df['City'].value_counts().head(11)
Most_affected_City
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: City, dtype: int64

# %%
# eliminating unknown city
Most_affected_City=Most_affected_City[1:12]
Most_affected_City
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: City, dtype: int64

# %%
plt.figure(figsize = (15,5))
sns.barplot(Most_affected_City.index, Most_affected_City.values)
plt.title('Top 10 most attacked City',fontsize=15)
plt.xlabel('City Names',fontsize=15)
plt.ylabel('No. of attacks',fontsize=15)
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# To get exact count of number of attack in the Most affected city we use Bar plot.

# %% [markdown]
# Observation:-
#
# 1.Similarly most number of attacks happen in the Baghdad city

# %% [markdown]
# ## Analysis based on Terrorist Organization

# %% [markdown]
# ###Top 10 Active Terrorist Organizations who attack the most

# %%
# Top 10 Active terrorist organizations around the world based on attacks
Active_Terrorist_Groups= new_df['Gang_Name'].value_counts().head(11)
Active_Terrorist_Groups
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Name: Gang_Name, dtype: int64

# %%
# eliminating unknown terrorist group
Active_Terrorist_Groups=Active_Terrorist_Groups[1:]

# %%
Active_Terrorist_Groups
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Name: Gang_Name, dtype: int64

# %%
plt.figure(figsize = (20,8))
sns.barplot(Active_Terrorist_Groups.values, Active_Terrorist_Groups.index,palette='viridis')
plt.title('Graph of top 10 Active terrorist Organization',fontsize=20)
plt.xlabel('Number of Terrorist Attacks',fontsize=15)
plt.ylabel('Terrorist Organization',fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# To find out the most Active Terrorist Organization in the world we need number of attacks per Terrorist Organization.If the number of attacks of the terrorist organization is more then we can say that it is most active organization.So to get exact figure of number of attacks of the organization we use bar plot

# %% [markdown]
# Observation:-
#
# 1. Taliban and Islamic State of Iraq and the Levant (ISIL) are the Most active terrorist Organization who attack the most around the world.
#
# 2. Taliban recorded most number of attacks.

# %% [markdown]
# ####2.Top 10 Dangerous Terrorist Organization who killed the most number of people

# %%
# Top 10 terrorist organization around the world based on number of people killed
Killed_per_organization=new_df.groupby('Gang_Name')['Killed'].sum().sort_values(ascending=False)[1:11]
Killed_per_organization
# Out:
# Gang_Name
# Islamic State of Iraq and the Levant (ISIL)         38923.0
# Taliban                                             29410.0
# Boko Haram                                          20328.0
# Shining Path (SL)                                   11601.0
# Liberation Tigers of Tamil Eelam (LTTE)             10989.0
# Al-Shabaab                                           9330.0
# Farabundo Marti National Liberation Front (FMLN)     8065.0
# Nicaraguan Democratic Force (FDN)                    6662.0
# Tehrik-i-Taliban Pakistan (TTP)                      6042.0
# Revolutionary Armed Forces of Colombia (FARC)        5661.0
# Name: Killed, dtype: float64

# %%
plt.figure(figsize = (20,8))
sns.barplot(Killed_per_organization.values, Killed_per_organization.index,palette='Reds_r')
plt.title('Graph of Top 10 Dangerous terrorist Organization',fontsize=20)
plt.xlabel('Number of people killed',fontsize=15)
plt.ylabel('Terrorist Organization',fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# To find out the most Dangerous Terrorist Organization in the world we need number of people killed per Terrorist Organization.If the number of people killed by the terrorist organization is more then we can say that it is most Dangerous organization.So to get exact figure of number of people killed by the organization we use bar plot.

# %% [markdown]
# Observation:-
#
# 1.Islamic State of Iraq and the Levant (ISIL) and Taliban is the most dangerous Terrorist Organization in the world which records highest kills 38923.0 and 29410.0 respectively
#
# 2.Out of all the top 10 Organizations, around 46% people killed by ISIL and Taliban organization.

# %% [markdown]
# ###Top 10 Most attcked targets by the Terrorist Organization

# %%
# Most Attacked targets
Targets=new_df['Main_Target'].value_counts()[0:10]

# %%
Targets
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: Main_Target, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.barplot(Targets.index,Targets.values)
plt.title('Most Attacked Targets by Terrorism Groups',fontsize=15)
plt.xlabel('Target type',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
plt.xticks(rotation=90)
plt.plot()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []

# %% [markdown]
# Observation:-
#
# 1.Main target of terrorist is private Citizens and Property followed by Millitary, Police and Government

# %% [markdown]
# ### Top 5 Most use weapon by Terrorist Organization

# %%
# Weopan used in terrorism activity
Most_use_weapon=new_df['Weapon_type'].value_counts()[0:5]
Most_use_weapon
# Out:
# Explosives    92426
# Firearms      58524
# Unknown       15157
# Incendiary    11135
# Melee          3655
# Name: Weapon_type, dtype: int64

# %%
plt.figure(figsize=(18,5))
sns.barplot(Most_use_weapon.index,Most_use_weapon.values)
plt.title('Most Used Weopans by Terrorism Groups',fontsize=15)
plt.xlabel('Type of weopans',fontsize=15)
plt.ylabel('Number of weopans',fontsize=15)
plt.xticks(rotation=80)
plt.plot()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []

# %% [markdown]
# It seen that explosives were used in around 51.09 % of the attacks, followed by Firearms accounted for 32.35% of the attacks.

# %%
plt.figure(figsize=(20,10))
explode=(0.01,0.05,0.1,0.1,0.1)
plt.pie(new_df['Weapon_type'].value_counts()[0:5], labels=new_df['Weapon_type'].value_counts().index[0:5],autopct='%1.2f%%',explode=explode,shadow=True,textprops={'fontsize': 12})
my_circle = plt.Circle( (0,0), 0.40, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('% of weopan used by Terrorist Organization', fontsize = 15)
plt.show()

# %% [markdown]
# ####*Why did you pick the specific chart?*

# %% [markdown]
# To get the Percentage use of Weopan by Terrorist Organization we use Pie Chart

# %% [markdown]
# ##**Countrywise analysis**

# %% [markdown]
# A function on each countrywise analysis, In that Terror attacks on top 10 cities of country,Active terrorist groups in respective country and Total casualties from 1970 to 2017.

# %%
def country_analysis(data , Country=None, line_color=None , palette=None , title =None):
    plt.figure(figsize = (17,10))
    #Plot 1
    plt.subplot(2,2,1)
    sns.countplot(y = data.loc[data['Country'] == Country]['City'] ,\
                  order = data.loc[data.Country == Country].City.value_counts()[:10].index,\
                  data = data ,\
                  palette = sns.color_palette(palette,10),\
                  edgecolor = sns.color_palette('dark',5))
    plt.xticks(rotation = 90)
    plt.title(f"Terror attacks on Top 10 cities of {Country}",weight = 'bold' ,fontsize = 15 ,loc = 'center')
    plt.xlabel('Count',fontsize = 15)
    plt.ylabel('City',fontsize = 15)
    #Plot 2
    plt.subplot(2,2,3)
    sns.countplot(x = data.query('Country == @Country').Gang_Name ,\
                  data = data ,\
                  order = data.query('Country == @Country').Gang_Name.value_counts()[:10].index[1:],\
                  palette = sns.color_palette(palette,7),\
                  edgecolor = sns.color_palette('dark',5))
    plt.title(f"Terrorist Groups active/were active in {Country}",weight = 'bold' ,fontsize = 15 , loc = 'center')
    plt.xticks(rotation =90)
    plt.xlabel('Group',fontsize = 15)
    plt.ylabel('Attack Count',fontsize = 15)
    

    # Plot 3
    plt.subplot(2,2,2)
    data.query('Country == @Country').groupby(['Year'])['Casualties'].sum().plot(xticks = data.loc[data.Country == Country].groupby(['Year'])['Casualties'].sum().index, rot=90 , color = line_color)
    plt.title(f"Total casualties from (1970 - 2017) in {Country}", fontdict = {'fontsize' : 15 , 'weight': 'bold' } , loc = 'center')
    plt.ylabel("Casualities" ,fontsize = 15)
    plt.xlabel('Year',fontsize = 15)

    #plot 4
    plt.subplot(2,2,4)
    sns.countplot(y = data.loc[data['Country'] == Country]['Main_Target'] ,\
                  order = data.loc[data.Country == Country].Main_Target.value_counts()[:10].index,\
                  data = data ,\
                  palette = sns.color_palette(palette,10),\
                  edgecolor = sns.color_palette('dark',5))
    plt.title(f"Most Attacked Targets by Terrorism Groups in {Country}",fontsize=15,weight='bold',loc='center')
    plt.xlabel('Target type',fontsize=15)
    plt.ylabel('Number of Attacks',fontsize=15)

    plt.subplots_adjust(wspace = 1 ,hspace =0.5 ,top = 0.5 , bottom = 0.1) 
    plt.tight_layout()  
    plt.show()

# %% [markdown]
# ###Country Iraq

# %%
# Analysis of country Iraq
country_analysis(new_df, Country ='Iraq', palette = 'inferno', line_color = 'crimson')

# %% [markdown]
# ####*Why did you pick the specific charts?*

# %% [markdown]
# here we are doing the country wise analysis of terrorist attacks and by using the bar plot we can easily find out the most affected city and most safe city of the country. also most active terrorist organization in the respective country and what are the main targets of terrorist attack by geting exact figures. We can also find out the trends in the casulties from the year 1970 to 2017.

# %% [markdown]
# Observation :-
# 1.Here we did the analysis of most affected country of terrorism Iraq.
#
# 2.most number of attacks happen in the Baghdad city of iraq
#
# 3.Islamic state of iraq and the levant (ISIL) is the most active terrorist organization in the  country which record highest attacks
#
# 4.The number of casualties increases per year till 2014 later it is decreses.
#
# 5.Main target of terrorist is private Citizens and Property followed by Police,Military,and Government

# %% [markdown]
# ###Country India

# %%
# Analysis of Country India
country_analysis(new_df, Country ='India', palette = 'inferno', line_color = 'crimson')

# %% [markdown]
# Observation :-
# 1.Here we did the analysis of most affected country of terrorism India.
#
# 2.most number of attacks happen in the Shrinagar city of iraq
#
# 3.Communist party of india-Maoist(cpi-Maoist) is the most active terrorist organization in the country which record highest attacks
#
# 4.The number of casualties varries per year from 1985 to 2014.
#
# 5.Main target of terrorist is private Citizens and Property followed by Police,Government and Business.

# %% [markdown]
# ##Conclusion

# %% [markdown]
# ***1. It was clear that numbers of terrorist attacks were increases from 2002-2004.
# Most of the attacks were done on year 2014 and
# Iraq is the most affected country from terrorism because most of the peoples killed in iraq. In Iraq maximum of 1570 peoples killed in single attack.
# As expected Baghdad is most affected city(and yes this is also called province).***
#
# ***2. Among all the regions "Middle East & North Africa" has the most number of killed people approx 1.4 Lakhs followed by "South-Asia" & "Sub-saharan Africa***
#
# ***3. "Taliban" is the most powerful, dangerous and the most active gang among all of the gangs, followed by "islamic state of iraq and the levant(isil)" and "shining path(SL)".***
#
# ***4. The most targetted attacks are on "Private Citizens & Property" which is approximately 40% and 10-20% is the target on "Military", "Police", "Government", "Business".***
#
# ***5. "It seen that explosives were used in around 51.09% of the attacks, followed by Firearms accounted for 32.35% of the attacks".***
